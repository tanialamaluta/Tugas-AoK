# %% [markdown]
#    <span style="font-family: script; font-size:3em;color:orange;">===========Display=============== </p>
#
#    <span style="font-family: script; font-size:1.5em;color:white;"> By : Group 9 </p>
#
#     - Glenn Budiman
#     - Nafilia Sumolang
#     - Kevin Tinamberan
#     - Tania Lamaluta
#     - Chandra Opi
#     - Nurul Salsabila

# %%
from IPython.display import Image
Image(filename="downloads/display2.jpg", width=500, height =600)

# %% [markdown]
# <span style="font-family: script; font-size:2.5em;color:gold;"> Perkembangan Teknologi Display </p>
#
#     Perkembangan teknologi komputer grafik dari masa ke masa harus juga diikuti dengan perkembangan teknologi display yang berfungsi sebagai alat keluaran dari grafik yang dibentuk agar dapat dinikmati oleh kita semua. Saat ini teknologi display yang paling populer dan paling banyak digunakan adalah LCD (Liquid Crystal Display), Teknologi LCD (Liquid Crystal Display) telah ada sejak beberapa tahun yang lalu, yang secara stabil menghasilkan begitu banyak produk baru yang tampilannya semakin baik.

# %% [markdown]
# <span style="font-family: script; font-size:1.7em;color:red;"> A. Cathode Ray Tube </p>

# %%
from IPython.display import Image
Image(filename="downloads/crt.jpg", width=400, height =500)

# %% [markdown]
#     Pada monitor CRT, layar penampil yang digunakan berupa tabung sinar katoda. Teknologi ini memunculkan tampilan pada monitor dengan cara memancarkan sinar elektron ke suatu titik di layar. Sinar tersebut akan diperkuat untuk menampilkan sisi terang dan diperlemah untuk sisi gelap. Teknologi CRT merupakan teknologi termurah dibanding dengan kedua teknologi yang lain.

# %% [markdown]
# <span style="font-family: script; font-size:1.7em;color:blue;"> B. Liquid Crystal Display (LCD) atau Flat Display Panel (FDP) </p>

# %%
from IPython.display import Image
Image(filename="downloads/lcd.jpg", width=400, height =500)

# %% [markdown]
#     Monitor LCD tidak lagi menggunakan tabung electron tetapi menggunakan sejenis kristal liquid yang dapat berpendar. Teknologi ini menghasilkan monitor yang dikenal dengan nama Flat Panel Display dengan layar berbentuk pipih, dan kemampuan resolusi yang lebih tinggi dibandingkan dengan CRT. Karena bentuknya yang pipih, maka monitor jenis flat tersebut menggunakan energi yang kecil dan banyak digunakan pada komputer portabel.

# %% [markdown]
# <span style="font-family: script; font-size:1.7em;color:Silver;"> C. Plasma Gas atau Organic Light Emitting Diode (OLED) </p>

# %%
from IPython.display import Image
Image(filename="downloads/oled.jpg", width=400, height =500)

# %% [markdown]
#     Monitor jenis ini menggabungkan teknologi CRT dengan LCD. Dengan teknologi yang dihasilkan, mampu membuat layar dengan ketipisan menyerupai LCD dan sudut pandang yang dapat selebar CRT. Plasma gas juga menggunakan fosfor seperti halnya pada teknologi CRT, tetapi layar pada plasma gas dapat perpendar tanpa adanya bantuan cahaya di belakang layar. Hal itu akan membuat energi yang diserap tidak sebesar monitor CRT.Kontras warna yang dihasilkan pun lebih baik dari LCD.

# %% [markdown]
# <span style="font-family: script; font-size:2.5em;color:gold;"> Video Graphic Adaptor (VGA - Card)
#
#     VGA Merupakan perangkat yang berfungsi untuk menerjemahkan atau mengubah sinyal  digital dari komputer menjadi tampilan grafis pada layar monitor.

# %%
from IPython.display import Image
Image(filename="downloads/display3.jpg", width=600, height =400)

# %% [markdown]
# <span style="font-family: script; font-size:2.5em;color:green;"> Resolution
#
#         Resolusi adalah sebuah istilah yang digunakan untuk menjelaskan banyaknya jumlah pixel / titik (lampu/warna) dalam satu layar dengan menggunakan perbandingan jumlah titik lebar (width) dan jumlah titik tinggi (height) dengan menggunakan satuan pixel.Umumnya istilah resolusi ini melekat pada alat-alat visual seperti monitor, layar smartphone, LED Videotron, LCD Screen,

# %%
from IPython.display import Image
Image(filename="downloads/resolusi.jpg", width=600, height =600)

# %%
! jt -t oceans16 -f fira -fs 115
